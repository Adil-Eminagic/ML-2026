# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data/ecommerce_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      1000 non-null   str
#  1   external_id     1000 non-null   int64
#  2   title           1000 non-null   str
#  3   brand           1000 non-null   str
#  4   category        1000 non-null   str
#  5   subcategory     0 non-null      float64
#  6   url             1000 non-null   str
#  7   source          1000 non-null   str
#  8   price_current   1000 non-null   float64
#  9   price_original  284 non-null    float64
#  10  currency        1000 non-null   str
#  11  discount_pct    284 non-null    float64
#  12  has_discount    1000 non-null   bool
#  13  rating_score    796 non-null    float64
#  14  reviews_count   1000 non-null   int64
#  15  availability    1000 non-null   str
#  16  description     1000 non-null   str
#  17  images_count    1000 non-null   int64
#  18  first_image     1000 non-null   str
#  19  tags            1000 non-null   str
#  20  scraped_at      1000 non-null   str
# dtypes: bool(1), float64(5), int64(3), str(12)
# memory usage: 157.4 KB

# %%
df.head()
# Out:
#                              product_id    external_id  \
# 0  9efc81ac-b34e-487a-b7a1-6fe9c9d7920b  9749998221059
# 1  6c26ff34-72d3-45d8-aa01-71e58253e3c6  8979986990555
# 2  b271d64f-790b-4561-af51-5ff5d7b0a132  9473792172229
# 3  f8beb32f-30b3-4128-b813-820780d2a67c   390919824546
# 4  bbbb408c-5460-457c-b4ca-55f0af33ee29  3016548993474
#
#                                  title   brand     category  subcategory  \
# 0                    Huawei Tablet Pro  Huawei  Electronics          NaN
# 1          Adidas Portable Hoodie Plus  Adidas      Fashion          NaN
# 2            Calvin Klein Sneakers Pro  Calvin      Fashion          NaN
# 3  Nestle Lightweight Dried Fruits Pro  Nestle         Food          NaN
# 4   Braun Portable Vacuum Cleaner 2024   Braun         Home          NaN
#
#                                                  url  source  price_current  \
# 0  https://www.amazon.com/product/huawei-tablet-p...  amazon        1487.49
# 1  https://www.amazon.com/product/adidas-portable...  amazon        1125.26
# 2  https://www.amazon.com/product/calvin-klein-sn...  amazon        1357.13
# 3  https://www.amazon.com/product/nestle-lightwei...  amazon        1553.58
# 4  https://www.amazon.com/product/braun-portable-...  amazon         509.81
#
#    price_original  ... discount_pct  has_discount  rating_score  \
# 0             NaN  ...          NaN         False           4.8
# 1         1575.36  ...         28.6          True           3.7
# 2             NaN  ...          NaN         False           3.9
# 3         1724.47  ...          9.9          True           4.1
# 4             NaN  ...          NaN         False           4.5
#
#    reviews_count  availability  \
# 0            177      in_stock
# 1            665  out_of_stock
# 2            379  out_of_stock
# 3              4       limited
# 4             88      in_stock
#
#                                          description images_count  \
# 0  Crafted with attention to detail and backed by...            1
# 1  A versatile product suitable for a wide range ...            1
# 2  Thoughtfully designed to deliver value without...            1
# 3  A trusted choice for professionals and enthusi...            1
# 4  Combining modern aesthetics with functional en...            1
#
#                                         first_image                tags  \
# 0  https://cdn.amazon.example/img/9749998221059.jpg  amazon|electronics
# 1  https://cdn.amazon.example/img/8979986990555.jpg      amazon|fashion
# 2  https://cdn.amazon.example/img/9473792172229.jpg      amazon|fashion
# 3  https://cdn.amazon.example/img/0390919824546.jpg         amazon|food
# 4  https://cdn.amazon.example/img/3016548993474.jpg         amazon|home
#
#                    scraped_at
# 0  2026-03-21T05:42:24.094706
# 1  2026-03-27T11:23:36.862451
# 2  2026-03-24T17:44:49.598673
# 3  2026-03-16T03:50:09.844085
# 4  2026-03-14T18:13:11.642972
#
# [5 rows x 21 columns]

# %%
df.drop(columns=["product_id", "external_id", "subcategory","url","first_image","tags"], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           1000 non-null   str
#  1   brand           1000 non-null   str
#  2   category        1000 non-null   str
#  3   source          1000 non-null   str
#  4   price_current   1000 non-null   float64
#  5   price_original  284 non-null    float64
#  6   currency        1000 non-null   str
#  7   discount_pct    284 non-null    float64
#  8   has_discount    1000 non-null   bool
#  9   rating_score    796 non-null    float64
#  10  reviews_count   1000 non-null   int64
#  11  availability    1000 non-null   str
#  12  description     1000 non-null   str
#  13  images_count    1000 non-null   int64
#  14  scraped_at      1000 non-null   str
# dtypes: bool(1), float64(4), int64(2), str(8)
# memory usage: 110.5 KB

# %% [markdown]
# # Descriptive Statistics

# %%
df.head()
# Out:
#                                  title   brand     category  source  \
# 0                    Huawei Tablet Pro  Huawei  Electronics  amazon
# 1          Adidas Portable Hoodie Plus  Adidas      Fashion  amazon
# 2            Calvin Klein Sneakers Pro  Calvin      Fashion  amazon
# 3  Nestle Lightweight Dried Fruits Pro  Nestle         Food  amazon
# 4   Braun Portable Vacuum Cleaner 2024   Braun         Home  amazon
#
#    price_current  price_original currency  discount_pct  has_discount  \
# 0        1487.49             NaN      USD           NaN         False
# 1        1125.26         1575.36      USD          28.6          True
# 2        1357.13             NaN      USD           NaN         False
# 3        1553.58         1724.47      USD           9.9          True
# 4         509.81             NaN      USD           NaN         False
#
#    rating_score  reviews_count  availability  \
# 0           4.8            177      in_stock
# 1           3.7            665  out_of_stock
# 2           3.9            379  out_of_stock
# 3           4.1              4       limited
# 4           4.5             88      in_stock
#
#                                          description  images_count  \
# 0  Crafted with attention to detail and backed by...             1
# 1  A versatile product suitable for a wide range ...             1
# 2  Thoughtfully designed to deliver value without...             1
# 3  A trusted choice for professionals and enthusi...             1
# 4  Combining modern aesthetics with functional en...             1
#
#                    scraped_at
# 0  2026-03-21T05:42:24.094706
# 1  2026-03-27T11:23:36.862451
# 2  2026-03-24T17:44:49.598673
# 3  2026-03-16T03:50:09.844085
# 4  2026-03-14T18:13:11.642972

# %%
print(df["reviews_count"].mean())
print(df["reviews_count"].median())
# Out:
# 265.373
# 160.0

# %%
plt.hist(df['reviews_count'])
plt.title("Reviews Count distribution")
plt.xlabel("Reviews Count")
plt.ylabel("Count")
plt.show()

# %%
# frequency

df["availability"].value_counts()
# Out:
# availability
# in_stock        834
# out_of_stock     85
# limited          81
# Name: count, dtype: int64

# %%
# relative frequency

df["availability"].value_counts(normalize=True)
# Out:
# availability
# in_stock        0.834
# out_of_stock    0.085
# limited         0.081
# Name: proportion, dtype: float64

# %%
df["availability"].unique()
# Out:
# <StringArray>
# ['in_stock', 'out_of_stock', 'limited']
# Length: 3, dtype: str

# %%
in_stock_count = df["availability"].value_counts()["in_stock"]
out_of_stock_count = df["availability"].value_counts()["out_of_stock"]
limited_count = df["availability"].value_counts()["limited"]

values = np.array([in_stock_count, out_of_stock_count, limited_count])

print(in_stock_count)
# Out:
# 834

# %%
plt.pie(values, labels=['in_stock', 'out_of_stock', 'limited'])
plt.show()

# %%
plt.bar(['in_stock', 'out_of_stock', 'limited'], values, color='blue')
plt.title('Availability')
plt.xlabel('Availability')
plt.ylabel('Count')
plt.show()
